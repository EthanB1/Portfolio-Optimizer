# %%
import panel as pn
from pathlib import Path
#pn.extension()
pn.extension('tabulator', template='material', sizing_mode='stretch_width')
from portfolio_dummies import portfolio_returns
import hvplot.pandas

# %%
# this is a test in place of real func temporarily
print(portfolio_returns.__doc__)
# Out:
# None

# %%
# this is a test in place of real func temporarily
img = Path('Images/cardholder_2_trans.png')
pn.pane.PNG(img,height=130)
# Out:
# PNG(str, height=130, sizing_mode='stretch_width')

# %%
dashboard_title = pn.panel('## Portfolio Optimization')
snp_dummy = pn.panel(img, height=130)
portfolio_return_dummy = portfolio_returns(5)
header = pn.Row(dashboard_title)
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# ...

# %%
portfolio_value_dummy = portfolio_return_dummy * 10000
portfolio_value_dummy.hvplot()
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)

# %%
amount_input = pn.widgets.TextInput(name='Initial Investing Amount', 
                                    placeholder='$10,000')
year_input = pn.widgets.TextInput(name='Years', placeholder='Years')
portfolio_return_plot = portfolio_return_dummy.hvplot()
portfolio_value_plot = portfolio_value_dummy.hvplot()
dashboard = pn.Column(
    header,
    pn.Row(amount_input,snp_dmy),
    pn.Row(year_input, portfolio_return_plot),
    pn.Row(portfolio_value_plot)
          )
dashboard
# Out:
# Column(sizing_mode='stretch_width')
#     [0] Row(sizing_mode='stretch_width')
#         [0] Markdown(str, sizing_mode='stretch_width')
#     [1] Row(sizing_mode='stretch_width')
#         [0] TextInput(name='Initial Investing A..., placeholder='$10,000', sizing_mode='stretch_width')
#         [1] HoloViews(NdOverlay, height=300, sizing_mode='fixed', width=700)
#     [2] Row(sizing_mode='stretch_width')
#         [0] TextInput(name='Years', placeholder='Years', sizing_mode='stretch_width')
#         [1] HoloViews(NdOverlay, height=300, sizing_mode='fixed', width=700)

# %%
text_input.value
# Out:
# 'abcdefg'

# %%
# Out:
# ERROR: Path for Bokeh server application does not exist: C:\Users\pi_ka\git_repo\project day 1\01-Stu_Create-Repository\Dashboards.ipynb
